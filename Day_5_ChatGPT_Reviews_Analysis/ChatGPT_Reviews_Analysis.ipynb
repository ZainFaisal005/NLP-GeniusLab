# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Caveat:wght@700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             background-color: #182c47;
#             color: #fff;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             width: 100%;
#             max-width: 1000px;
#             background-color: #1f3a58;
#             border: 1px solid #ccc;
#             border-radius: 8px;
#             padding: 20px;
#             box-shadow: 0 8px 16px rgba(0, 0, 128, 0.2); /* Changed box shadow color to dark blue */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             font-size: 2.1em;
#             margin-top: 0;
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🌟📋 In-Depth Analysis of ChatGPT Reviews 🔍🌟</h1>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #87CEEB; /* Sky blue background color */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 1000px; /* Adjusted max-width slightly */
#             background-color: #87CEEB; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>👍 If you find this notebook helpful, please upvote it! 👍</h1>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 500px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📚 Importing Libraries 📥</h1>
# </div>
#
# </body>
# </html>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import emoji
import nltk
import spacy
from tqdm import tqdm
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import MinMaxScaler, LabelEncoder, OrdinalEncoder

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 480px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📊✨ Importing Data 🌟📈</h1>
# </div>
#
# </body>
# </html>

# %%
df = pd.read_csv('chatgpt_reviews.csv')
df = df.sample(1000)
df.head()
# Out:
#                                     reviewId                userName  \
# 104653  8a6cf80c-c0d6-4a01-a301-e6f393bba5da      Kolurejo Alexander
# 102656  d2b2fc80-3177-4b5c-9798-60837e812b4b         Akshansh Mishra
# 9492    b0a98c7a-d9a1-4a90-a955-276e501afc25            Pallav Ghosh
# 69244   97f18c6f-a225-4fc2-bae4-559fdbff6a05  Damon Anderson (Unk75)
# 93561   d044f46c-f8b7-497a-a870-def7876e8eaf   Bryan Madriaga Lexter
#
#                                                   content  score  \
# 104653                                             ❤️❤️❤️      5
# 102656                                        Progressive      4
# 9492    I'm delighted to report that the previous issu...      5
# 69244                                      so far so good      4
# 93561                                     THANKYOU SOMUCH      5
#
#         thumbsUpCount reviewCreatedVersion                   at  appVersion
# 104653              0           1.2023.314  2023-12-08 16:18:13  1.2023.314
# ...

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 730px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📋 Header View of ChatGPT Reviews 👀</h1>
# </div>
#
# </body>
# </html>

# %%
pd.DataFrame(df['content']).head()
# Out:
#                                                   content
# 104653                                             ❤️❤️❤️
# 102656                                        Progressive
# 9492    I'm delighted to report that the previous issu...
# 69244                                      so far so good
# 93561                                     THANKYOU SOMUCH

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Caveat:wght@700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             background-color: #182c47;
#             color: #fff;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             width: 100%;
#             max-width: 1000px;
#             background-color: #1f3a58;
#             border: 1px solid #ccc;
#             border-radius: 8px;
#             padding: 20px;
#             box-shadow: 0 8px 16px rgba(0, 0, 128, 0.2); /* Changed box shadow color to dark blue */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             font-size: 2.1em;
#             margin-top: 0;
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🔍 Overview of Data 🗂️</h1>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 730px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📏 Distribution of Rows and Columns 📐</h1>
# </div>
#
# </body>
# </html>

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 400px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🔍 Data Information 🗃️</h1>
# </div>
#
# </body>
# </html>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 104653 to 53168
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              1000 non-null   object
#  1   userName              1000 non-null   object
#  2   content               1000 non-null   object
#  3   score                 1000 non-null   int64
#  4   thumbsUpCount         1000 non-null   int64
#  5   reviewCreatedVersion  911 non-null    object
#  6   at                    1000 non-null   object
#  7   appVersion            911 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 70.3+ KB

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 420px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📈 Data Description 📊</h1>
# </div>
#
# </body>
# </html>

# %%
df.describe()
# Out:
#             score  thumbsUpCount
# count  1000.00000     1000.00000
# mean      4.53500        0.20100
# std       1.01084        2.60603
# min       1.00000        0.00000
# 25%       5.00000        0.00000
# 50%       5.00000        0.00000
# 75%       5.00000        0.00000
# max       5.00000       55.00000

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 490px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🚩 Sum of Null Values 🚫</h1>
# </div>
#
# </body>
# </html>

# %%
df.isnull().sum()
# Out:
# reviewId                 0
# userName                 0
# content                  0
# score                    0
# thumbsUpCount            0
# reviewCreatedVersion    89
# at                       0
# appVersion              89
# dtype: int64

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Caveat:wght@700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             background-color: #182c47;
#             color: #fff;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             width: 100%;
#             max-width: 1000px;
#             background-color: #1f3a58;
#             border: 1px solid #ccc;
#             border-radius: 8px;
#             padding: 20px;
#             box-shadow: 0 8px 16px rgba(0, 0, 128, 0.2); /* Changed box shadow color to dark blue */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             font-size: 2.1em;
#             margin-top: 0;
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🧹 Data Cleaning 🧽</h1>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 500px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🧹 Dropping Duplicates 🗑️</h1>
# </div>
#
# </body>
# </html>

# %%
df = df.drop_duplicates()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 620px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🧹 Dropping Rows with Null Values ✂️</h1>
# </div>
#
# </body>
# </html>

# %%
df = df.dropna()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 540px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📏 Revised Data Shape 📏</h1>
# </div>
#
# </body>
# </html>

# %%
df.shape
# Out:
# (911, 8)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 540px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📊 Score Value Counts 📊</h1>
# </div>
#
# </body>
# </html>

# %%
df['score'].value_counts()
# Out:
# score
# 5    694
# 4    119
# 3     46
# 1     41
# 2     11
# Name: count, dtype: int64

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 710px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>👍 ThumbsUpCount Value Counts 👍</h1>
# </div>
#
# </body>
# </html>

# %%
df['thumbsUpCount'].value_counts()
# Out:
# thumbsUpCount
# 0     879
# 1      18
# 2       5
# 5       2
# 3       2
# 11      1
# 55      1
# 54      1
# 16      1
# 20      1
# Name: count, dtype: int64

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Caveat:wght@700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             background-color: #182c47;
#             color: #fff;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             width: 100%;
#             max-width: 1000px;
#             background-color: #1f3a58;
#             border: 1px solid #ccc;
#             border-radius: 8px;
#             padding: 20px;
#             box-shadow: 0 8px 16px rgba(0, 0, 128, 0.2); /* Changed box shadow color to dark blue */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             font-size: 2.1em;
#             margin-top: 0;
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📊 Visualizing Data 📊</h1>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 710px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📊 Histogram of Numerical Columns 📊</h1>
# </div>
#
# </body>
# </html>

# %%
df.hist(figsize=(15, 5))
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 730px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📉 Scatter Plot of Numerical Columns 📉</h1>
# </div>
#
# </body>
# </html>

# %%
sns.scatterplot(x='score', y='thumbsUpCount', data=df)
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Caveat:wght@700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             background-color: #182c47;
#             color: #fff;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             width: 100%;
#             max-width: 1000px;
#             background-color: #1f3a58;
#             border: 1px solid #ccc;
#             border-radius: 8px;
#             padding: 20px;
#             box-shadow: 0 8px 16px rgba(0, 0, 128, 0.2); /* Changed box shadow color to dark blue */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             font-size: 2.1em;
#             margin-top: 0;
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🔧 Feature Engineering 🛠️</h1>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 670px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📌 Selecting Relevant Features 📌</h1>
# </div>
#
# </body>
# </html>

# %%
df.drop(columns=['reviewId', 'userName', 'at'], inplace=True)

# %%
df.head()
# Out:
#                                                   content  score  \
# 104653                                             ❤️❤️❤️      5
# 102656                                        Progressive      4
# 9492    I'm delighted to report that the previous issu...      5
# 69244                                      so far so good      4
# 93561                                     THANKYOU SOMUCH      5
#
#         thumbsUpCount reviewCreatedVersion  appVersion
# 104653              0           1.2023.314  1.2023.314
# 102656              0           1.2023.319  1.2023.319
# 9492                0           1.2023.352  1.2023.352
# 69244               0             1.0.0031    1.0.0031
# 93561               0           1.2024.052  1.2024.052

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 480px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🔄 Encoding Columns 🔢</h1>
# </div>
#
# </body>
# </html>

# %%
le = LabelEncoder()
df['reviewCreatedVersion'] = le.fit_transform(df['reviewCreatedVersion'])

# %%
oe = OrdinalEncoder()
df['appVersion'] = oe.fit_transform(df[['appVersion']])

# %%
df.head()
# Out:
#                                                   content  score  \
# 104653                                             ❤️❤️❤️      5
# 102656                                        Progressive      4
# 9492    I'm delighted to report that the previous issu...      5
# 69244                                      so far so good      4
# 93561                                     THANKYOU SOMUCH      5
#
#         thumbsUpCount  reviewCreatedVersion  appVersion
# 104653              0                    19        19.0
# 102656              0                    20        20.0
# 9492                0                    23        23.0
# 69244               0                     5         5.0
# 93561               0                    30        30.0

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Caveat:wght@700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             background-color: #182c47;
#             color: #fff;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             width: 100%;
#             max-width: 1000px;
#             background-color: #1f3a58;
#             border: 1px solid #ccc;
#             border-radius: 8px;
#             padding: 20px;
#             box-shadow: 0 8px 16px rgba(0, 0, 128, 0.2); /* Changed box shadow color to dark blue */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             font-size: 2.1em;
#             margin-top: 0;
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📝 Applying NLP to Review Content 🧠</h1>
# </div>
#
# </body>
# </html>

# %%
df['content']
# Out:
# 104653                                               ❤️❤️❤️
# 102656                                          Progressive
# 9492      I'm delighted to report that the previous issu...
# 69244                                        so far so good
# 93561                                       THANKYOU SOMUCH
#                                 ...
# 75773                                               awesome
# 54383                                       the best friend
# 40380     Mr (most respected)chatgpt please provide phot...
# 101291                                            Great app
# 53168                                       It's Phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 500px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🔠 Converting to Lowercase 🔡</h1>
# </div>
#
# </body>
# </html>

# %%
df['content'] = df['content'].str.lower()

# %%
df['content']
# Out:
# 104653                                               ❤️❤️❤️
# 102656                                          progressive
# 9492      i'm delighted to report that the previous issu...
# 69244                                        so far so good
# 93561                                       thankyou somuch
#                                 ...
# 75773                                               awesome
# 54383                                       the best friend
# 40380     mr (most respected)chatgpt please provide phot...
# 101291                                            great app
# 53168                                       it's phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 500px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🏷️ Removing HTML Tags 🏷️</h1>
# </div>
#
# </body>
# </html>

# %%
def remove_html_tags(text):
    clean_text = re.sub('<.*?>', '', text)
    return clean_text

# %%
df['content'] = df['content'].apply(remove_html_tags)

# %%
df['content']
# Out:
# 104653                                               ❤️❤️❤️
# 102656                                          progressive
# 9492      i'm delighted to report that the previous issu...
# 69244                                        so far so good
# 93561                                       thankyou somuch
#                                 ...
# 75773                                               awesome
# 54383                                       the best friend
# 40380     mr (most respected)chatgpt please provide phot...
# 101291                                            great app
# 53168                                       it's phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 470px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🔗 Removing URLs 🌐</h1>
# </div>
#
# </body>
# </html>

# %%
def remove_urls(text):
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    clean_text = re.sub(url_pattern, '', text)
    return clean_text

# %%
df['content'] = df['content'].apply(remove_urls)

# %%
df['content']
# Out:
# 104653                                               ❤️❤️❤️
# 102656                                          progressive
# 9492      i'm delighted to report that the previous issu...
# 69244                                        so far so good
# 93561                                       thankyou somuch
#                                 ...
# 75773                                               awesome
# 54383                                       the best friend
# 40380     mr (most respected)chatgpt please provide phot...
# 101291                                            great app
# 53168                                       it's phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 555px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>✂️ Removing Punctuation ✏️</h1>
# </div>
#
# </body>
# </html>

# %%
def remove_punctuation(text):
    punctuation = string.punctuation
    clean_text = text.translate(str.maketrans('', '', punctuation))
    return clean_text

# %%
df['content'] = df['content'].apply(remove_punctuation)

# %%
df['content']
# Out:
# 104653                                               ❤️❤️❤️
# 102656                                          progressive
# 9492      im delighted to report that the previous issue...
# 69244                                        so far so good
# 93561                                       thankyou somuch
#                                 ...
# 75773                                               awesome
# 54383                                       the best friend
# 40380     mr most respectedchatgpt please provide photo ...
# 101291                                            great app
# 53168                                        its phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 540px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>💬 Chat Word Treatment 🗨️</h1>
# </div>
#
# </body>
# </html>

# %%
chat_words_mapping = {
    "lol": "laughing out loud",
    "brb": "be right back",
    "btw": "by the way",
    "afk": "away from keyboard",
    "rofl": "rolling on the floor laughing",
    "ttyl": "talk to you later",
    "np": "no problem",
    "thx": "thanks",
    "omg": "oh my god",
    "idk": "I don't know",
    "np": "no problem",
    "gg": "good game",
    "g2g": "got to go",
    "b4": "before",
    "cu": "see you",
    "yw": "you're welcome",
    "wtf": "what the f*ck",
    "imho": "in my humble opinion",
    "jk": "just kidding",
    "gf": "girlfriend",
    "bf": "boyfriend",
    "u": "you",
    "r": "are",
    "2": "to",
    "4": "for",
    "b": "be",
    "c": "see",
    "y": "why",
    "tho": "though",
    "smh": "shaking my head",
    "lolz": "laughing out loud",
    "h8": "hate",
    "luv": "love",
    "pls": "please",
    "sry": "sorry",
    "tbh": "to be honest",
    "omw": "on my way",
    "omw2syg": "on my way to see your girlfriend",
}

def expand_chat_words(text):
    words = text.split()
    expanded_words = [chat_words_mapping.get(word.lower(), word) for word in words]
    return ' '.join(expanded_words)

# %%
df['content'] = df['content'].apply(expand_chat_words)

# %%
df['content']
# Out:
# 104653                                               ❤️❤️❤️
# 102656                                          progressive
# 9492      im delighted to report that the previous issue...
# 69244                                        so far so good
# 93561                                       thankyou somuch
#                                 ...
# 75773                                               awesome
# 54383                                       the best friend
# 40380     mr most respectedchatgpt please provide photo ...
# 101291                                            great app
# 53168                                        its phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 550px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🚫 Removing Stop Words 🚫</h1>
# </div>
#
# </body>
# </html>

# %%
def remove_stop_words(text):
	tokens = nltk.word_tokenize(text)
	stop_words = set(stopwords.words('english'))
	filtered_tokens = [token for token in tokens if token not in stop_words]
	preprocessed_text = ' '.join(filtered_tokens)
	return preprocessed_text

# %%
df['content'] = df['content'].apply(remove_stop_words)

# %%
df['content']
# Out:
# 104653                                               ❤️❤️❤️
# 102656                                          progressive
# 9492      im delighted report previous issue encountered...
# 69244                                              far good
# 93561                                       thankyou somuch
#                                 ...
# 75773                                               awesome
# 54383                                           best friend
# 40380     mr respectedchatgpt please provide photo visua...
# 101291                                            great app
# 53168                                            phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 750px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>😊 Replacing Emojis with Meanings 😊</h1>
# </div>
#
# </body>
# </html>

# %%
def replace_emojis_with_meanings(text):
    def replace(match):
        emoji_char = match.group()
        emoji_meaning = emoji.demojize(emoji_char)
        return emoji_meaning

    emoji_pattern = re.compile("["
                            u"\U0001F600-\U0001F64F"
                            u"\U0001F300-\U0001F5FF"
                            u"\U0001F680-\U0001F6FF"
                            u"\U0001F1E0-\U0001F1FF"
                            u"\U00002500-\U00002BEF"
                            u"\U00002702-\U000027B0"
                            u"\U00002702-\U000027B0"
                            u"\U000024C2-\U0001F251"
                            u"\U0001f926-\U0001f937"
                            u"\U00010000-\U0010ffff"
                            u"\u2640-\u2642"
                            u"\u2600-\u2B55"
                            u"\u200d"
                            u"\u23cf"
                            u"\u23e9"
                            u"\u231a"
                            u"\ufe0f"
                            u"\u3030"
                            "]+", flags=re.UNICODE)
    text_with_meanings = emoji_pattern.sub(replace, text)
    return text_with_meanings

# %%
df['content'] = df['content'].apply(replace_emojis_with_meanings)

# %%
df['content']
# Out:
# 104653                    :red_heart::red_heart::red_heart:
# 102656                                          progressive
# 9492      im delighted report previous issue encountered...
# 69244                                              far good
# 93561                                       thankyou somuch
#                                 ...
# 75773                                               awesome
# 54383                                           best friend
# 40380     mr respectedchatgpt please provide photo visua...
# 101291                                            great app
# 53168                                            phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 480px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>✂️ Word Tokenization ✂️</h1>
# </div>
#
# </body>
# </html>

# %%
def word_tokenization(text):
    return nltk.word_tokenize(text)

# %%
df['token_content'] = df['content'].apply(word_tokenization)

# %%
df['content']
# Out:
# 104653                    :red_heart::red_heart::red_heart:
# 102656                                          progressive
# 9492      im delighted report previous issue encountered...
# 69244                                              far good
# 93561                                       thankyou somuch
#                                 ...
# 75773                                               awesome
# 54383                                           best friend
# 40380     mr respectedchatgpt please provide photo visua...
# 101291                                            great app
# 53168                                            phenomenal
# Name: content, Length: 911, dtype: object

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 400px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🔖 POS Tagging 🏷️</h1>
# </div>
#
# </body>
# </html>

# %%
nlp = spacy.load('en_core_web_sm', disable=['ner', 'textcat'])

def batch_pos_tagging(texts):
    docs = list(nlp.pipe(texts, batch_size=50))
    return [[(token.text, token.pos_) for token in doc] for doc in docs]

batch_size = 50
num_batches = len(df) // batch_size + 1

pos_tags = []
for i in tqdm(range(num_batches)):
    start = i * batch_size
    end = start + batch_size
    batch_texts = df['content'][start:end].tolist()
    pos_tags.extend(batch_pos_tagging(batch_texts))

df['POS_Tags'] = pos_tags
# Out:
# 100%|██████████| 19/19 [00:01<00:00, 15.80it/s]

# %%
df['POS_Tags']
# Out:
# 104653    [(:, PUNCT), (red_heart::red_heart::red_heart,...
# 102656                                 [(progressive, ADJ)]
# 9492      [(i, PRON), (m, VERB), (delighted, ADJ), (repo...
# 69244                             [(far, ADV), (good, ADJ)]
# 93561                   [(thankyou, PROPN), (somuch, VERB)]
#                                 ...
# 75773                                      [(awesome, ADJ)]
# 54383                         [(best, ADJ), (friend, NOUN)]
# 40380     [(mr, PROPN), (respectedchatgpt, NOUN), (pleas...
# 101291                          [(great, ADJ), (app, NOUN)]
# 53168                                   [(phenomenal, ADJ)]
# Name: POS_Tags, Length: 911, dtype: object

# %%
df.head()
# Out:
#                                                   content  score  \
# 104653                  :red_heart::red_heart::red_heart:      5
# 102656                                        progressive      4
# 9492    im delighted report previous issue encountered...      5
# 69244                                            far good      4
# 93561                                     thankyou somuch      5
#
#         thumbsUpCount  reviewCreatedVersion  appVersion  \
# 104653              0                    19        19.0
# 102656              0                    20        20.0
# 9492                0                    23        23.0
# 69244               0                     5         5.0
# 93561               0                    30        30.0
#
#                                             token_content  \
# 104653    [:, red_heart, :, :red_heart, :, :red_heart, :]
# 102656                                      [progressive]
# ...

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 420px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📦 Bag of Words 📦</h1>
# </div>
#
# </body>
# </html>

# %%
df['content'] = df['content'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
df['token_content'] = df['token_content'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
df['POS_Tags'] = df['POS_Tags'].apply(lambda x: ' '.join(str(i) for i in x) if isinstance(x, list) else x)

vectorizer = CountVectorizer(ngram_range=(2, 2))

bow_c = vectorizer.fit_transform(df['content'])
bow_t = vectorizer.fit_transform(df['token_content'])
bow_pos = vectorizer.fit_transform(df['POS_Tags'])

df['content'] = bow_c.toarray()
df['token_content'] = bow_t.toarray()
df['POS_Tags'] = bow_pos.toarray()

# %%
df.head()
# Out:
#         content  score  thumbsUpCount  reviewCreatedVersion  appVersion  \
# 104653        0      5              0                    19        19.0
# 102656        0      4              0                    20        20.0
# 9492          0      5              0                    23        23.0
# 69244         0      4              0                     5         5.0
# 93561         0      5              0                    30        30.0
#
#         token_content  POS_Tags
# 104653              0         0
# 102656              0         0
# 9492                0         0
# 69244               0         0
# 93561               0         0

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Caveat:wght@700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             background-color: #182c47;
#             color: #fff;
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             width: 100%;
#             max-width: 1000px;
#             background-color: #1f3a58;
#             border: 1px solid #ccc;
#             border-radius: 8px;
#             padding: 20px;
#             box-shadow: 0 8px 16px rgba(0, 0, 128, 0.2); /* Changed box shadow color to dark blue */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Palatino', 'Palatino Linotype', serif;
#             font-size: 2.1em;
#             margin-top: 0;
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>📈 Predictive Modeling 🤖</h1>
# </div>
#
# </body>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 540px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🔄 Train-Test Split of Data 🔀</h1>
# </div>
#
# </body>
# </html>

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['score']), df['score'], test_size=0.2, random_state=41)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 740px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🌳 Decision Tree Model and Evaluation 🌳</h1>
# </div>
#
# </body>
# </html>

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dt.predict(X_test)

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         9
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00        27
#            5       0.76      0.99      0.86       137
#
#     accuracy                           0.74       183
#    macro avg       0.15      0.20      0.17       183
# weighted avg       0.57      0.74      0.64       183

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm)

fig, ax = plt.subplots(figsize=(5, 5))
cm_display.plot(ax=ax)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #f0f4f8; /* Changed background to a light shade */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 770px; /* Adjusted max-width slightly */
#             background-color: #ffffff; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>🌲 Random Forest Model and Evaluation 🌲</h1>
# </div>
#
# </body>
# </html>

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
print(classification_report(y_test, y_pred, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         9
#            2       0.00      0.00      0.00         1
#            3       0.00      0.00      0.00         9
#            4       0.00      0.00      0.00        27
#            5       0.75      0.99      0.85       137
#
#     accuracy                           0.74       183
#    macro avg       0.15      0.20      0.17       183
# weighted avg       0.56      0.74      0.64       183

# %%
cm = confusion_matrix(y_test, y_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix=cm)

fig, ax = plt.subplots(figsize=(5, 5))
cm_display.plot(ax=ax)
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Analysis of ChatGPT Reviews</title>
#     <link href="https://fonts.googleapis.com/css2?family=Roboto:wght@400;700&display=swap" rel="stylesheet">
#     <style>
#         body {
#             font-family: 'Roboto', sans-serif;
#             background-color: #87CEEB; /* Sky blue background color */
#             color: #333; /* Changed text color to a dark shade */
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             margin: 0;
#         }
#         .notebook-interface {
#             width: 100%;
#             max-width: 1000px; /* Adjusted max-width slightly */
#             background-color: #87CEEB; /* Changed box background to white */
#             border: 1px solid #ccc;
#             border-radius: 8px; /* Slightly more rounded corners */
#             padding: 10px; /* Increased padding */
#             box-shadow: 0 8px 16px rgba(0, 0, 0, 0.1); /* Softer shadow */
#             text-align: center;
#         }
#         .notebook-interface h1 {
#             font-family: 'Roboto', sans-serif;
#             font-size: 2.0em; /* Increased font size */
#             margin-top: 0;
#             margin-bottom: 20px;
#             color: #0073e6; /* Added a color to the title for emphasis */
#         }
#     </style>
# </head>
# <body>
#
# <div class="notebook-interface">
#     <h1>😊 Thank you very much 🌟</h1>
# </div>
#
# </body>
# </html>
